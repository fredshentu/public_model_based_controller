# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
save_path = '/Users/dianchen/state.npy'
data = np.load(save_path)
n, d = data.shape

# %%
for i in range(d):
    plt.figure()
    plt.hist(data[:, i])
    plt.title('Dim %d' % i)
